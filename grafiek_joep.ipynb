# %%
import plotly.graph_objs as go
import plotly.express as px
import matplotlib.pyplot as plt
import pandas as pd

# %%
df1 = pd.read_csv('happiness_2020-def.csv')

df1
# Out:
#    Unnamed: 0 Country name  Happiness score  Dystopia + residual  \
# 0           2          CHE           7.5599             2.350267
# 1           5          NLD           7.4489             2.352117
# 2           7          NZL           7.2996             2.128108
# 3          10          CAN           7.2321             2.195269
# 4          26          SAU           6.4065             2.203119
# 5          38          CHL           6.2285             2.283013
# 6          58          PRT           5.9109             1.752559
# 7          93          CHN           5.1239             1.336182
# 8         108          ZAF           4.8141             1.625117
# 9         143          IND           3.5733             0.734131
#
#    Explained by: Log GDP per capita  Explained by: Social support  \
# 0                          1.390774                      1.472403
# 1                          1.338946                      1.463646
# 2                          1.242318                      1.487218
# 3                          1.301648                      1.435392
# 4                          1.334329                      1.309950
# 5                          1.096992                      1.323287
# 6                          1.168801                      1.339530
# 7                          0.990533                      1.132081
# 8                          0.902140                      1.259086
# 9                          0.730576                      0.644199
#
#    Explained by: Healthy life expectancy  \
# 0                               1.040533
# 1                               0.975675
# 2                               1.008138
# 3                               1.022502
# 4                               0.759818
# 5                               0.889261
# 6                               0.979315
# 7                               0.867249
# 8                               0.407034
# 9                               0.540570
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                    0.628954                  0.269056
# 1                                    0.613626                  0.336318
# 2                                    0.646790                  0.325726
# 3                                    0.644028                  0.281529
# 4                                    0.548477                  0.087441
# 5                                    0.417482                  0.155579
# 6                                    0.589895                  0.053037
# 7                                    0.601605                  0.079021
# 8                                    0.434782                  0.126407
# 9                                    0.581142                  0.237072
#
#    Explained by: Perceptions of corruption
# 0                                 0.407946
# 1                                 0.368570
# 2                                 0.461268
# 3                                 0.351702
# 4                                 0.163322
# 5                                 0.062849
# 6                                 0.027733
# 7                                 0.117256
# 8                                 0.059502
# 9                                 0.105588

# %%
df2 = pd.read_csv('happiness_2022-def.csv')

df2
# Out:
#    Unnamed: 0 Country  Happiness score  Dystopia (1.83) + residual  \
# 0           3     CHE            7.512                       2.153
# 1           4     NLD            7.415                       2.137
# 2           9     NZL            7.200                       1.954
# 3          14     CAN            7.025                       1.924
# 4          24     SAU            6.523                       2.075
# 5          43     CHL            6.172                       2.040
# 6          55     PRT            6.016                       1.691
# 7          71     CHN            5.585                       1.516
# 8          90     ZAF            5.194                       1.742
# 9         135     IND            3.777                       0.795
#
#    Explained by: GDP per capita  Explained by: Social support  \
# 0                         2.026                         1.226
# 1                         1.945                         1.206
# 2                         1.852                         1.235
# 3                         1.886                         1.188
# 4                         1.870                         1.092
# 5                         1.651                         1.080
# 6                         1.760                         1.078
# 7                         1.508                         0.958
# 8                         1.425                         1.088
# 9                         1.167                         0.376
#
#    Explained by: Healthy life expectancy  \
# 0                                  0.822
# 1                                  0.787
# 2                                  0.752
# 3                                  0.783
# 4                                  0.577
# 5                                  0.748
# 6                                  0.777
# 7                                  0.705
# 8                                  0.361
# 9                                  0.471
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                       0.677                     0.147
# 1                                       0.651                     0.271
# 2                                       0.680                     0.245
# 3                                       0.659                     0.217
# 4                                       0.651                     0.078
# 5                                       0.460                     0.124
# 6                                       0.655                     0.016
# 7                                       0.656                     0.099
# 8                                       0.442                     0.089
# 9                                       0.647                     0.198
#
#    Explained by: Perceptions of corruption
# 0                                    0.461
# 1                                    0.419
# 2                                    0.483
# 3                                    0.368
# 4                                    0.180
# 5                                    0.069
# 6                                    0.039
# 7                                    0.142
# 8                                    0.046
# 9                                    0.123

# %%
df3 = pd.read_csv('Data_inflatie.csv')
df3 = df3[df3["TIME"]=="2020"]
df3 = df3[df3["SUBJECT"]=="TOT"]
df3 = df3[df3["MEASURE"]=="IDX2015"]
countries = ["CHE", "NLD", "NZL", "CAN", "SAU", "CHL", "PRT", "CHN", "ZAF", "IND"]
df3 = df3[df3['LOCATION'].isin(countries)]
    
df3
# Out:
#        LOCATION INDICATOR SUBJECT  MEASURE FREQUENCY  TIME     Value  \
# 146211      CAN       CPI     TOT  IDX2015         A  2020  108.2104
# 149430      NLD       CPI     TOT  IDX2015         A  2020  107.5100
# 149731      NZL       CPI     TOT  IDX2015         A  2020  107.6488
# 150321      PRT       CPI     TOT  IDX2015         A  2020  103.3332
# 151167      CHE       CPI     TOT  IDX2015         A  2020  100.6647
# 152108      CHL       CPI     TOT  IDX2015         A  2020  114.8052
# 152192      CHN       CPI     TOT  IDX2015         A  2020  111.4750
# 152622      IND       CPI     TOT  IDX2015         A  2020  128.1744
# 153215      SAU       CPI     TOT  IDX2015         A  2020  105.0286
# 153475      ZAF       CPI     TOT  IDX2015         A  2020  125.9030
#
#        Flag Codes
# 146211        NaN
# 149430        NaN
# 149731        NaN
# 150321        NaN
# 151167        NaN
# 152108        NaN
# 152192        NaN
# 152622        NaN
# 153215        NaN
# 153475        NaN

# %%
df4 = pd.read_csv('Data_inflatie.csv')
df4 = df4[df4["TIME"]=="2022"]
df4 = df4[df4["SUBJECT"]=="TOT"]
df4 = df4[df4["MEASURE"]=="IDX2015"]
countries = ["CHE", "NLD", "NZL", "CAN", "SAU", "CHL", "PRT", "CHN", "ZAF", "IND"]
df4 = df4[df4['LOCATION'].isin(countries)]
    
df4
# Out:
#        LOCATION INDICATOR SUBJECT  MEASURE FREQUENCY  TIME     Value  \
# 146213      CAN       CPI     TOT  IDX2015         A  2022  119.4957
# 149432      NLD       CPI     TOT  IDX2015         A  2022  121.4267
# 149733      NZL       CPI     TOT  IDX2015         A  2022  119.9165
# 150323      PRT       CPI     TOT  IDX2015         A  2022  112.8373
# 151169      CHE       CPI     TOT  IDX2015         A  2022  104.1208
# 152110      CHL       CPI     TOT  IDX2015         A  2022  133.9722
# 152194      CHN       CPI     TOT  IDX2015         A  2022  114.7902
# 152624      IND       CPI     TOT  IDX2015         A  2022  142.3749
# 153217      SAU       CPI     TOT  IDX2015         A  2022  110.9241
# 153477      ZAF       CPI     TOT  IDX2015         A  2022  140.9812
#
#        Flag Codes
# 146213        NaN
# 149432        NaN
# 149733        NaN
# 150323        NaN
# 151169        NaN
# 152110        NaN
# 152194        NaN
# 152624        NaN
# 153217        NaN
# 153477        NaN

# %%
# Maak van de x-as 2 getallen in plaats van 3 getallen
df3["Value"] = df3["Value"] - 100
df4["Value"] = df4["Value"] - 100

# Plot de punten in de grafiek
plt.scatter(df3["Value"], df1["Happiness score"], label="2020")
plt.scatter(df4["Value"], df2["Happiness score"], label="2022")

# Geef labels aan de assen
plt.xlabel('Increase in inflation compared to 2015 (%)')
plt.ylabel('Happiness Score')

# Voeg labels toe aan de punten
for x, y, label in zip(df3["Value"], df1["Happiness score"], df3["LOCATION"]):
    plt.text(x, y, label, ha='center', va='bottom')
for x, y, label in zip(df4["Value"], df2["Happiness score"], df4["LOCATION"]):
    plt.text(x, y, label, ha='center', va='bottom')

# Trek lijnen tussen de punten voor overzicht
plt.plot([df3["Value"], df4["Value"]], [df1["Happiness score"], df2["Happiness score"]], 'k-')
plt.title("Happiness and inflation in countries")

#
plt.legend()

# Toon de grafiek
plt.show()

# %%
#The graph shown above is a scatterplot that shows the correlation between happiness in a country and the
#increased inflation in said country. The y-axis shows the "Happiness Score" that each country received. This indicates the
#happiness of inhabitants from this country on a scale of 1 to 10.
#The dots are labeled by country code. The blue dots represent said country in the year 2020, and the orange dots represent
#said country in 2022. The x-axis shows the increase in inflation compared to the year 2015. Where an increase in 10% means
#that prices in this country are 110% of what they used to be in the year 2015. The lines between the dots function to easily
#show an increase or decrease in happiness. With this graph we aimed to either confirm or debunk one of our perspectives.
#The remarkeble result is that there is no clear pattern in the scatterplot. We do see that every country has seen an increase
#in inflation. However some countries have increased their happiness score, while others have seen a decrease in happiness.
#This means that we can not confirm nor debunk either one of our perspectives. This does show that there is no clear correlation
#between the inflation of a country and the happiness of the inhabitants of said country.
# Out:
# 'The graph shown above is a scatterplot that shows the correlation between happiness in a country and the '
